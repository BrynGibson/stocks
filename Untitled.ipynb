# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %%
data_path = Path(r"C:\Users\sloth\stonks\data\built")

# %%
ticker = "tsla"

# %%
tick_path = data_path / f"{ticker}.csv"

# %%
df = pd.read_csv(tick_path, parse_dates=["Date"], index_col="Date")

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-06   88.094002   90.311996   88.000000   90.307999   90.307999
# 2020-01-07   92.279999   94.325996   90.671997   93.811996   93.811996
# 2020-01-08   94.739998   99.697998   93.646004   98.428001   98.428001
# 2020-01-09   99.419998   99.760002   94.573997   96.267998   96.267998
# 2020-01-10   96.358002   96.987999   94.739998   95.629997   95.629997
# ...                ...         ...         ...         ...         ...
# 2020-04-22  140.796005  146.800003  137.742004  146.421997  146.421997
# 2020-04-23  145.520004  146.800003  140.626007  141.126007  141.126007
# 2020-04-24  142.162003  146.145996  139.636002  145.029999  145.029999
# 2020-04-27  147.522003  159.897995  147.000000  159.750000  159.750000
# 2020-04-28  159.128006  161.000000  151.337997  153.824005  153.824005
#
#                Volume  Name  positive_mentions  negative_mentions  \
# Date
# 2020-01-06   50665000  tsla                  1                  0
# 2020-01-07   89410500  tsla                  8                  3
# 2020-01-08  155721500  tsla                 22                 18
# 2020-01-09  142202000  tsla                 10                  3
# 2020-01-10   64797500  tsla                  7                  5
# ...               ...   ...                ...                ...
# 2020-04-22   70827500  tsla                  9                  8
# 2020-04-23   66183500  tsla                  0                  1
# 2020-04-24   66060000  tsla                  1                  0
# 2020-04-27  103407000  tsla                 17                 21
# 2020-04-28   76110000  tsla                  3                  1
#
#             neutral_mentions  total_mentions
# Date
# 2020-01-06                11              12
# 2020-01-07                25              36
# 2020-01-08               164             204
# 2020-01-09                28              41
# 2020-01-10                42              54
# ...                      ...             ...
# 2020-04-22                48              65
# 2020-04-23                17              18
# 2020-04-24                27              28
# 2020-04-27               284             322
# 2020-04-28                35              39
#
# [79 rows x 11 columns]

# %%
plt.rcParams["figure.figsize"] = (20,5)



fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_title(f'{ticker} price vs total mentions')
ax1.set_xlabel('time (d)')
ax1.set_ylabel('price (usd)', color=color)
ax1.plot(df["Adj Close"], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('total mentions', color=color)  # we already handled the x-label with ax1
ax2.plot(df["total_mentions"], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
plt.rcParams["figure.figsize"] = (20,5)



fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_title(f'{ticker} price vs positive mentions')
ax1.set_xlabel('time (d)')
ax1.set_ylabel('price (usd)', color=color)
ax1.plot(df["Adj Close"], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('positive mentions', color=color)  # we already handled the x-label with ax1
ax2.plot(df["positive_mentions"], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
plt.rcParams["figure.figsize"] = (20,5)



fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_title(f'{ticker} price vs negative mentions')
ax1.set_xlabel('time (d)')
ax1.set_ylabel('price (usd)', color=color)
ax1.plot(df["Adj Close"], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('negative mentions', color=color)  # we already handled the x-label with ax1
ax2.plot(df["negative_mentions"], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
x = df["total_mentions"]
y = df["Adj Close"]

r, p = scipy.stats.pearsonr(x,y)

# %%
r
# Out:
# 0.21116725834908479

# %%
p
# Out:
# 0.06174746158541931
