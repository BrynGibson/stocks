# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re


base_path = Path(r'C:\Users\sloth\stonks\data')

sub_red = "pennystocks"
parsed_path = base_path / "sentiment"

out_path = base_path / "counted" / sub_red

Path.mkdir(out_path, exist_ok=True, parents=True)

sub_path = parsed_path / sub_red

files = set(sub_path.glob("*.csv"))

done_files = set(out_path.glob("*.csv"))
files = files - done_files

tickers_path = Path("./data/cleaned_listings.csv")

tickers_df = pd.read_csv(tickers_path)

# %%
tickers_df
# Out:
#       symbol                                    name   exchange assetType  \
# 0          A                Agilent Technologies Inc       NYSE     Stock
# 1         AA                              Alcoa Corp       NYSE     Stock
# 2        AAA         AAF First Priority CLO Bond ETF  NYSE ARCA       ETF
# 3       AAAU         Goldman Sachs Physical Gold ETF  NYSE ARCA       ETF
# 4        AAC  Ares Acquisition Corporation - Class A       NYSE     Stock
# ...      ...                                     ...        ...       ...
# 11031   ZYME                           Zymeworks Inc       NYSE     Stock
# 11032   ZYNE             Zynerba Pharmaceuticals Inc     NASDAQ     Stock
# 11033   ZYXI                               Zynex Inc     NASDAQ     Stock
# 11034    ZZK                                     NaN  NYSE ARCA     Stock
# 11035    ZZZ                     TEST TICKER FOR UTP  NYSE ARCA     Stock
#
#           ipoDate  delistingDate  status                    fixed_name
# ...

# %%
def count_post(post):
    mentions = []
    
    
    for ticker, name in zip(tickers_df["symbol"], tickers_df["fixed_name"]):
        ticker = re.escape(ticker)
        if pd.isnull(ticker):
            continue
        if pd.isnull(name):
            exp = r"\$"+ticker+"([,/]|\.|\s)"
        else:
            name = re.escape(name)
            exp = r"(\$"+ticker+"(,|\.|\s)"+"|((,|\s|\$|\.)"+name+r"([,/]|\.|\s))"
            
           
            
        
    
        if re.search(exp, post, flags=re.IGNORECASE | re.MULTILINE):
            mentions.append(ticker)
    
    print("done")
    return str(mentions)

# %%
(\$ayro[,|\.|\s])|([,|\s|\$|\.]ayiro[,|\.|\s])

# %%
df["mentions"]=df["cleaned"].apply(count_post)
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
len(df["cleaned"])
# Out:
# 337

# %%
df["mentions"]
# Out:
# 0      ['A', 'ADI', 'AMRK', 'ANY', 'AONE', 'BE', 'CAN...
# 1        ['AM', 'ARE', 'GOOD', 'IMAB', 'IT', 'SO', 'SY']
# 2                                           ['ME', 'OR']
# 3             ['ARE', 'FOR', 'IMAB', 'NOW', 'OR', 'TWO']
# 4                               ['AYRO', 'CTXR', 'FLWS']
#                              ...
# 332           ['A', 'ALL', 'AMRK', 'HOLD', 'IMAB', 'ON']
# 333    ['A', 'ALL', 'AMRK', 'AONE', 'ARE', 'AYRO', 'B...
# 334                                              ['ARE']
# 335    ['A', 'AM', 'AMRK', 'BE', 'FLWS', 'IMAB', 'ON'...
# 336       ['A', 'AI', 'AMRK', 'FOR', 'HAS', 'NEW', 'OR']
# Name: mentions, Length: 337, dtype: object

# %%
df["cleaned"].isna().sum()
# Out:
# 0

# %%
df = pd.read_csv(list(files)[0])
df["cleaned"][4]
# Out:
# "For limit buys AYRO I'm thinking $2.9 and CTXR $1.4"

# %%
df["cleaned"][45]
# Out:
# ' Copy and paste..."An optimist from america.... I\'m bullish, but the maths is certainly not as simple as deducting the additional debt from the market cap. It\'s about the ability to service the debt out of NOI- and $6.5B is a far cry from $2,5B in debt service. that\'s what they are working on- getting the creditors to agree to debt restructure (and possibly reduction thru equity) at a longer term and lower rate. Obviously the debt holders would rather take worse terms than be subject to a liquidation, which is why they are playing ball. Once again, biggest holder is ADCB, which is 65% owned by ADIA (Abu Dhabi Investment Authority, SWF), so you have debt held by the world\'s 3rd largest sovereign wealth fund which obviously has a high incentive to keep their largest health operator solvent and keep 20k people employed. That\'s the story- I like our chances, but the news is going to be about creditors agreeing to new terms- which is why the CEO\'s memo on the 3 year turnaround plan
# ...

# %%
count_post("as")
# Out:
# ('A', 'Agilent Technologies ')
# ('AA', 'Alcoa ')
# ('AAA', 'AAF First Priority CLO Bond ')
# ('AAAU', 'Goldman Sachs Physical Gold ')
# ('AAC', 'Ares Acquisition  ')
# ('AAC-U', 'Ares Acquisition  ')
# ('AAC-WS', 'Ares Acquisition  ')
# ('AACQ', 'Artius Acquisition  ')
# ('AACQU', 'Artius Acquisition  ')
# ('AACQW', 'Artius Acquisition  ')
# ('AADR', 'AdvisorShares Dorsey Wright ADR ')
# ('AAIC', 'Arlingtosset Investment  ')
# ('AAIC-P-B', 'Arlingtosset Investment ')
# ('AAIC-P-C', 'Arlingtosset Investment ')
# ('AAL', 'Americairlines Group ')
# ('AAMC', 'Altisource Asset Magement ')
# ('AAME', 'Atlantic American ')
# ('AAN', 'Aarons Company  (The)')
# ('AAN-W', 'Aarons Holdings Company  When Issued')
# ('AAOI', 'Applied Optoelectronics ')
# ('AAON', 'AAON ')
# ('AAP', 'Advance Auto Parts ')
# ('AAPL', 'Apple ')
# ('AAQC', 'Accelerate Acquisition  ')
# ('AAQC-U', 'Accelerate Acquisition  ')
# ('AAQC-WS', 'Accelerate Acquisition  ')
# ('AAT', 'Americassets Trust ')
# ...

# %%
def count_df(df):

# %%
base_path = Path('~/stonks/data')

sub_red = "pennystocks"
parsed_path = base_path / "clean"

out_path = base_path / "sentiment" / sub_red

Path.mkdir(out_path, exist_ok=True, parents=True)

sub_path = parsed_path / sub_red

files = set(sub_path.glob("*.csv"))

done_files = set(out_path.glob("*.csv"))
files = files - done_files

# %%
base_path.exists()
# Out:
# True

# %%
parsed_path.exists()
# Out:
# False

# %%
parsed_path
# Out:
# WindowsPath('~/stonks/data/clean')

# %%
Path('~/stonks/data/clean').exists()
# Out:
# False

# %%
parsed_path.absolute()
# Out:
# WindowsPath('C:/Users/sloth/Desktop/stonks/stonks/~/stonks/data/clean')

# %%
base_path.absolute()
# Out:
# WindowsPath('C:/Users/sloth/Desktop/stonks/stonks/~/stonks/data')

# %%
base_path = Path('C:/Users/sloth/stonks/data/clean/pennystocks')

# %%
base_path.exists()
# Out:
# True
